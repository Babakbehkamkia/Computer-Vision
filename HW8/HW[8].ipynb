# %%
# !sudo apt install tesseract-ocr
# !pip install pytesseract
# Out:
# Reading package lists... Done
# Building dependency tree
# Reading state information... Done
# The following package was automatically installed and is no longer required:
#   libnvidia-common-460
# Use 'sudo apt autoremove' to remove it.
# The following additional packages will be installed:
#   tesseract-ocr-eng tesseract-ocr-osd
# The following NEW packages will be installed:
#   tesseract-ocr tesseract-ocr-eng tesseract-ocr-osd
# 0 upgraded, 3 newly installed, 0 to remove and 7 not upgraded.
# Need to get 4,795 kB of archives.
# After this operation, 15.8 MB of additional disk space will be used.
# Get:1 http://archive.ubuntu.com/ubuntu bionic/universe amd64 tesseract-ocr-eng all 4.00~git24-0e00fe6-1.2 [1,588 kB]
# Get:2 http://archive.ubuntu.com/ubuntu bionic/universe amd64 tesseract-ocr-osd all 4.00~git24-0e00fe6-1.2 [2,989 kB]
# Get:3 http://archive.ubuntu.com/ubuntu bionic/universe amd64 tesseract-ocr amd64 4.00~git2288-10f4998a-2 [218 kB]
# ...

# %%
# !sudo apt-get install tesseract-ocr-fas
# Out:
# Reading package lists... Done
# Building dependency tree
# Reading state information... Done
# The following package was automatically installed and is no longer required:
#   libnvidia-common-460
# Use 'sudo apt autoremove' to remove it.
# The following NEW packages will be installed:
#   tesseract-ocr-fas
# 0 upgraded, 1 newly installed, 0 to remove and 7 not upgraded.
# Need to get 301 kB of archives.
# After this operation, 446 kB of additional disk space will be used.
# Get:1 http://archive.ubuntu.com/ubuntu bionic/universe amd64 tesseract-ocr-fas all 4.00~git24-0e00fe6-1.2 [301 kB]
# Fetched 301 kB in 0s (1,433 kB/s)
# debconf: unable to initialize frontend: Dialog
# debconf: (No usable dialog-like program is installed, so the dialog based frontend cannot be used. at /usr/share/perl5/Debconf/FrontEnd/Dialog.pm line 76, <> line 1.)
# debconf: falling back to frontend: Readline
# debconf: unable to initialize frontend: Readline
# ...

# %%
from google.colab import drive
drive.mount('/content/drive')

path = "/content/drive/My Drive/CV_course/HW8/"
# Out:
# Mounted at /content/drive

# %% [markdown]
# # **الف:**

# %%
# Import required packages
import cv2
import pytesseract
from google.colab.patches import cv2_imshow
from PIL import Image

##################### your code ################################
img = cv2.imread(path + 'royan.jpg')
img = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY )
ret,th = cv2.threshold(img,0,255,cv2.THRESH_OTSU)
# kernel = cv2.getStructuringElement(cv2.MORPH_RECT, (3, 3))
# dilation = cv2.dilate(th, kernel, 1)
th2 = cv2.adaptiveThreshold(img,100,cv2.ADAPTIVE_THRESH_MEAN_C, cv2.THRESH_BINARY,21,5)
print(pytesseract.image_to_string(img, lang='fas'))
print("==================== OTSU ===================")
print(pytesseract.image_to_string(th, lang='fas'))
print("==================== adaptiveThreshold ===================")
print(pytesseract.image_to_string(th2, lang='fas'))



################################################################
# Finding contours
## result = result otso|adaptive algorithm
# print(pytesseract.image_to_string( result , lang='fas'))
# Out:
#
#
# ۳
#
# تیم‌های بر
#
# کادر پزشکی و اما
# فرهنگی «جهاد دان: ؟]
# و برگزار می‌کردیم بو
#
# ن معمولا با گروه پانزده‌بیست‌نفره ا٩
#
# بهیاری و امدادگری را تمام کرده بودند. به ۲
#
# و بعد از اتسمام عملیات دوباره
#
# دانشگاه می شد یم (د: ۱ ۳ ۲
#
# 8۰
# سا تفگیم آن ۳۳ نیا ۱
# قف مضا ۳ ۵ تیید سک
# ص22 :
# صی
#
# | ادا
# تس نت اتف مات میتی ۱۳ ها باز
# شد دوهی +,.هوقدرارتساط با محیط ]را 0 ۹
# دیزی . با ایین وضعیت معلو 4
# م نبود ج)
#
# تارب آن روزها بیاید؛جولی
#
# 9
# باوجود همه دوک
# ۵ «جهاد ورازیی‌گاهی)
#
# کت + قیا های رو
#
# ه أن روز 9
# | کردنك؛ موش
#
# ى فاد
#
#
#
# ==================== OTSU ===================
#
#
# تبم‌های یر
#
# کادر پزشکی و ام
# فرهنگی «جهاد دان:_ ؟!
# ری برگزار می‌کردیم ۳
#
# ن معمولا با گروه پانزده‌بیست‌نفره ا٩
#
# بهیاری و امدادگری را تمام کرده بودند. به ۱
#
# و بعد از اتسمام عملیات دوباره
#
# دانشگاه می‌ شدیم .. : یشنم
#
# 4
# ۳۳ ام دم میا یبا ۱
# 0 تم ‌ یچ و ۱
#
# ی 9 :
# مه
#
# ا ادا
# ات دامه داشت تا ایرکه ه سل ۱۳۶۲ مجدد داز ها باز
# ...

# %%
cv2_imshow(th)
# Out:
# <PIL.Image.Image image mode=L size=3540x5267>

# %%
cv2_imshow(th2)
# Out:
# <PIL.Image.Image image mode=L size=3540x5267>

# %%
image_path_in_colab='.....'
extractedInformation = pytesseract.image_to_string(image_path_in_colab, lang='fas')
print(extractedInformation)

# %% [markdown]
# # **ب:**

# %%
# Import required packages
import cv2
import pytesseract
from google.colab.patches import cv2_imshow
from PIL import Image
##################### your code ################################
img = cv2.imread(path + 'mypic.png')
img = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY )
print(pytesseract.image_to_string(img, lang='fas'))
ret,th = cv2.threshold(img,0,255,cv2.THRESH_OTSU)
kernel = cv2.getStructuringElement(cv2.MORPH_RECT, (3, 3))
dilation = cv2.dilate(th, kernel, 1)


################################################################
# Finding contours
im2 = img.copy()
contours, hierarchy = cv2.findContours(dilation, cv2.RETR_EXTERNAL,cv2.CHAIN_APPROX_NONE)

for cnt in contours:
  x, y, w, h = cv2.boundingRect(cnt)
	# Drawing a rectangle on copied image
  rect = cv2.rectangle(im2, (x, y), (x + w, y + h), (0, 255, 0), 2)
	# Cropping the text block for giving input to OCR
  cropped = im2[y:y + h, x:x + w]
  print(pytesseract.image_to_string(cropped, lang='fas'))
# Out:
# نلم: بابک
#
# نام خانوادگی: بهکلم کیا
#
# شماره داتشجویی: 98521099
#
# نام کتاب مورد علااله: تندتر از عقربه ها حرکت کن
#
#
#
# نلم: بابک
#
# نام خانوادگی: بهکلم کیا
#
# شماره داتشجویی: 98521099
#
# نام کتاب مورد علااله: تندتر از عقربه ها حرکت کن

# %%
image_path_in_colab='....'
extractedInformation = pytesseract.image_to_string(image_path_in_colab, lang='fas')
print(extractedInformation)
